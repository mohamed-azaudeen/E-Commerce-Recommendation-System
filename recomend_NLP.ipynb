# %%
import pandas as pd
import numpy as np
import re
from scipy.sparse import csr_matrix
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv(r"C:\Users\ISMAIMZ\OneDrive - Hapag-Lloyd AG\Documents\Books\Projects\Recommendation system\archive\clean_data.csv")

# %%
df.drop(columns=["Unnamed: 0", "ImageURL"], inplace=True)

# %%
df.head(5)
# Out:
#            ID  ProdID  Rating  ReviewCount  \
# 0  1705736792       2     0.0          0.0
# 1          95      76     0.0          0.0
# 2           8       8     4.5      29221.0
# 3           4       3     0.0          0.0
# 4         990       3     0.0        131.0
#
#                                             Category             Brand  \
# 0  premium, beauty, premium, makeup, premium, nai...               opi
# 1  beauty, hair, care, hair, color, auburn, hair,...              easy
# 2  beauty, hair, care, hair, color, permanent, ha...           clairol
# 3                                beauty, makeup, lip  kokie, cosmetics
# 4  seasonal, stock, essentials, personal, care, s...          gillette
#
#                                                 Name  \
# 0  OPI Infinite Shine, Nail Lacquer Nail Polish, ...
# 1  Nice n Easy Permanent Color, 111 Natural Mediu...
# 2  Clairol Nice N Easy Permanent Color 7/106A Nat...
# 3  Kokie Professional Matte Lipstick, Hot Berry, ...
# 4  Gillette TRAC II Plus Razor Blade Refills, Fit...
#
#                                          Description  \
# 0                                                NaN
# 1  pack, 3, pack, 3, upc, 381519000201, beautiful...
# 2  clairol, nice, n, easy, permanent, color, give...
# 3  calling, matte, lip, lovers, indulge, rich, cr...
# 4  1971, gillette, introduced, trac, ii, razor, s...
#
#                                                 Tags
# 0  premium, beauty, premium, makeup, premium, nai...
# 1  beauty, hair, care, hair, color, auburn, hair,...
# 2  beauty, hair, care, hair, color, permanent, ha...
# 3  beauty, makeup, lip, kokie, cosmetics, calling...
# 4  seasonal, stock, essentials, personal, care, s...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4090 entries, 0 to 4089
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4090 non-null   int64
#  1   ProdID       4090 non-null   int64
#  2   Rating       4090 non-null   float64
#  3   ReviewCount  4090 non-null   float64
#  4   Category     4081 non-null   object
#  5   Brand        3994 non-null   object
#  6   Name         4090 non-null   object
#  7   Description  3174 non-null   object
#  8   Tags         4090 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 287.7+ KB

# %%
df.columns
# Out:
# Index(['ID', 'ProdID', 'Rating', 'ReviewCount', 'Category', 'Brand', 'Name',
#        'Description', 'Tags'],
#       dtype='object')

# %%
for col in ['Category', 'Brand', 'Name','Description', 'Tags']:
    df[col] = df[col].fillna("")

def clean(s):
    s = s.lower()
    s = re.sub(r"[^a-z0-9\s]", " ",s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

for col in ['Category', 'Brand', 'Name','Description', 'Tags']:
    df[col] = df[col].astype(str).map(clean)

df["doc"] = (df["Name"] + " " + df["Brand"] + " " + df["Category"] + " " +
             df["Description"] + " " + df["Tags"])

df["Rating"] = df["Rating"].fillna(0)
df["ReviewCount"] = df["ReviewCount"].fillna(0)

rating = (df["Rating"] - df["Rating"].min()) / (df["Rating"].max() - df["Rating"].min() + 1e-9)
reviews = np.log1p(df["ReviewCount"])
reviews = (reviews - reviews.min()) / (reviews.max() - reviews.min() + 1e-9)
alpha = 0.6
df["Pop_Score"] = alpha * rating + (1 + alpha) * reviews

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4090 entries, 0 to 4089
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4090 non-null   int64
#  1   ProdID       4090 non-null   int64
#  2   Rating       4090 non-null   float64
#  3   ReviewCount  4090 non-null   float64
#  4   Category     4090 non-null   object
#  5   Brand        4090 non-null   object
#  6   Name         4090 non-null   object
#  7   Description  4090 non-null   object
#  8   Tags         4090 non-null   object
#  9   doc          4090 non-null   object
#  10  Pop_Score    4090 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 351.6+ KB

# %%
df.head(10)
# Out:
#            ID      ProdID  Rating  ReviewCount  \
# 0  1705736792           2     0.0          0.0
# 1          95          76     0.0          0.0
# 2           8           8     4.5      29221.0
# 3           4           3     0.0          0.0
# 4         990           3     0.0        131.0
# 5         262 -2147483648     4.6         52.0
# 6 -2147483648         371     4.3         10.0
# 7           6           0     0.0          0.0
# 8         507 -2147483648     5.0          1.0
# 9          32 -2147483648     0.0        950.0
#
#                                             Category            Brand  \
# 0  premium beauty premium makeup premium nail pol...              opi
# 1      beauty hair care hair color auburn hair color             easy
# 2   beauty hair care hair color permanent hair color          clairol
# 3                                  beauty makeup lip  kokie cosmetics
# 4  seasonal stock essentials personal care stock ...         gillette
# 5  beauty hair care hair care brands old spice ha...        old spice
# 6             personal care oral care kids oral care          colgate
# 7                                beauty makeup nails              bmc
# 8            beauty hair care hair care brands suave            suave
# 9                           health lip care vaseline         vaseline
#
#                                                 Name  \
# 0  opi infinite shine nail lacquer nail polish bu...
# 1  nice n easy permanent color 111 natural medium...
# 2  clairol nice n easy permanent color 7 106a nat...
# 3  kokie professional matte lipstick hot berry 0 ...
# 4  gillette trac ii plus razor blade refills fit ...
# 5  old spice artisan styling high hold matte fini...
# 6  colgate my first baby and toddler toothpaste f...
# 7  bmc bright and loud cream gel lacquer polish s...
# 8   suave extra hold 7 shaping mousse 9 oz pack of 6
# 9  3 pack vaseline lip therapy tinted lip balm mi...
#
#                                          Description  \
# 0
# 1  pack 3 pack 3 upc 381519000201 beautiful natur...
# 2  clairol nice n easy permanent color gives 8 we...
# 3  calling matte lip lovers indulge rich creamy m...
# 4  1971 gillette introduced trac ii razor system ...
# 5  old spice artisan molding clay mens styling pr...
# 6  colgate baby toddler toothpaste safe fluoride ...
# 7  lights sick beats epic gel polish present neon...
# 8  free shipping pack 6 pack 6 upc 079400816603 y...
# 9  vaseline lip therapy lip balm mini rosy clinic...
#
#                                                 Tags  \
# 0  premium beauty premium makeup premium nail pol...
# 1  beauty hair care hair color auburn hair color ...
# 2  beauty hair care hair color permanent hair col...
# 3  beauty makeup lip kokie cosmetics calling matt...
# 4  seasonal stock essentials personal care stock ...
# 5  beauty hair care hair care brands old spice ha...
# 6  personal care oral care kids oral care colgate...
# 7  beauty makeup nails bmc lights sick beats epic...
# 8  beauty hair care hair care brands suave suave ...
# 9  health lip care vaseline vaseline vaseline lip...
#
#                                                  doc  Pop_Score
# 0  opi infinite shine nail lacquer nail polish bu...   0.000000
# 1  nice n easy permanent color 111 natural medium...   0.000000
# 2  clairol nice n easy permanent color 7 106a nat...   2.139888
# 3  kokie professional matte lipstick hot berry 0 ...   0.000000
# 4  gillette trac ii plus razor blade refills fit ...   0.759718
# 5  old spice artisan styling high hold matte fini...   1.169740
# 6  colgate my first baby and toddler toothpaste f...   0.889090
# 7  bmc bright and loud cream gel lacquer polish s...   0.000000
# 8  suave extra hold 7 shaping mousse 9 oz pack of...   0.707847
# 9  3 pack vaseline lip therapy tinted lip balm mi...   1.066965

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

tfidf = TfidfVectorizer(min_df=3, ngram_range=(1,2), stop_words="english", max_features=200000)
X = tfidf.fit_transform(df["doc"])
sim = cosine_similarity(X, X)
id_to_idx = {pid:i for i, pid in enumerate(df["ProdID"])}
idx_to_id = {i:pid for pid, i in id_to_idx.items()}

# %%
def similar_items(prod_id, k=10, w_pop=0.2):
    i = id_to_idx[prod_id]
    scores = sim[i].copy()
    scores = (1 - w_pop) * scores + w_pop * df["Pop_Score"].values
    scores[i] = -np.inf
    top_idx = np.argsort(-scores)[:k]
    return df.iloc[top_idx][["ProdID","Name","Brand","Category","Rating","ReviewCount"]]

# %%
similar_items(prod_id=156, k=5)
# Out:
#       ProdID                                               Name     Brand  \
# 3524       8  pine sol multi surface cleaner original 144 oz...    clorox
# 1053   43880   pine sol all purpose cleaner lemon 144 oz bottle  pine sol
# 1383      62      aquaphor ointment body spray 3 7 oz spray can  aquaphor
# 2          8  clairol nice n easy permanent color 7 106a nat...   clairol
# 614       53  clairol nice n easy permanent hair color 4 120...   clairol
#
#                                                Category  Rating  ReviewCount
# 3524  household essentials cleaning supplies purpose...     4.7      20997.0
# 1053  household essentials cleaning supplies purpose...     4.8       9806.0
# 1383      personal care men essentials men body lotions     4.0       6669.0
# 2      beauty hair care hair color permanent hair color     4.5      29221.0
# 614    beauty hair care hair color permanent hair color     4.5      29221.0

# %%
def recommend_from_history(prod_ids, k=10, w_pop=0.2):
    if isinstance(prod_ids, int):
        prod_ids = [prod_ids]
    idxs = [id_to_idx[p] for p in prod_ids if p in id_to_idx]
    if not idxs:
        return df.sort_values("Pop_Score", ascending=False).head(k)[["ProdID","Name","Brand","Category","Rating","ReviewCount"]]
    profile = np.asarray(X[idxs].mean(axis=0)).ravel()
    scores = cosine_similarity(profile.reshape(1, -1), X).ravel()
    scores = (1 - w_pop) * scores + w_pop * df["Pop_Score"].values

    for i in idxs: 
        scores[i] = -np.inf
        
    top_idx = np.argsort(-scores)[:k]
    return df.iloc[top_idx][["ProdID","Name","Brand","Category","Rating","ReviewCount"]]

# %%
recommend_from_history([156, 101], k=5)
# Out:
#       ProdID                                               Name         Brand  \
# 2133       8  redken color extend magnetics sulfate free sha...        redken
# 3581      56   kevin murphy balancing wash daily shampoo 8 4 oz  kevin murphy
# 295        3         living proof perfect hair day shampoo 8 oz  living proof
# 1078     955      biolage volumebloom cotton shampoo 33 8 fl oz        matrix
# 3497       3  redken diamond oil glow dry detangling conditi...        redken
#
#                                                Category  Rating  ReviewCount
# 2133  premium beauty premium hair care hair tools pr...     4.5        326.0
# 3581  premium beauty premium hair care hair tools pr...     5.0          2.0
# 295   premium beauty premium hair care hair tools pr...     4.3         12.0
# 1078  premium beauty premium hair care hair tools pr...     0.0         13.0
# 3497  premium beauty premium hair care hair tools pr...     4.5        334.0

# %%
def diversified_top_picks(k=10):
    cand = df.copy()
    cand["score"] = cand["Pop_Score"]
    top = []
    seen_cat = set()
    for _, row in cand.sort_values("score", ascending=False).iterrows():
        cat = row["Category"].split(",")[0] if row["Category"] else "misc"
        if cat not in seen_cat or len(top) < k//2:
            top.append(row)
            seen_cat.add(cat)
        if len(top) >= k:
            break
    return pd.DataFrame(top)[["ProdID","Name","Brand","Category","Rating","ReviewCount"]]

# %%
diversified_top_picks(5)
# Out:
#       ProdID                                               Name    Brand  \
# 2          8  clairol nice n easy permanent color 7 106a nat...  clairol
# 196      252  clairol nice n easy permanent color 6g 116a na...  clairol
# 3524       8  pine sol multi surface cleaner original 144 oz...   clorox
# 323    31287      clairol age defy expert collection hair color  clairol
# 365      970  garnier whole blends repairing shampoo honey t...  garnier
#
#                                                Category  Rating  ReviewCount
# 2      beauty hair care hair color permanent hair color     4.5      29221.0
# 196    beauty hair care hair color permanent hair color     4.5      29221.0
# 3524  household essentials cleaning supplies purpose...     4.7      20997.0
# 323      beauty hair care hair color clairol hair color     4.3      22002.0
# 365   beauty hair care hair care brands garnier hair...     4.7      13809.0

# %%
def category_consistency(recs_df, query_cat_tokens):
    tokens = set(query_cat_tokens.split())
    matches = recs_df["Category"].apply(lambda s: len(tokens & set(s.split())) > 0)
    return matches.mean()

# %%
query = "beauty skincare"
recs = recommend_from_history([252, 970], k=5)  # your recommender output
score = category_consistency(recs, query)
print(f"Category consistency: {score*100:.2f} %")
# Out:
# Category consistency: 100.00 %

# %%
queries = {
    "yoga fitness": [205, 309],
    "beauty skincare": [1443, 2133],
    "electronics audio": [5001, 5002]
}

results = []
for q, prod_ids in queries.items():
    recs = recommend_from_history(prod_ids, k=5)
    score = category_consistency(recs, q)
    results.append({"query": q, "score": score})

eval_df = pd.DataFrame(results)
print(eval_df)
print("Average consistency:", eval_df["score"].mean())
# Out:
#                query  score
# 0       yoga fitness    0.6
# 1    beauty skincare    1.0
# 2  electronics audio    0.0
# Average consistency: 0.5333333333333333
